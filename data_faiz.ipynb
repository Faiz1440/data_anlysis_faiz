# %% [markdown]
# ## data anlysis

# %% [markdown]
# ### import useful labrary here

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("netflix.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
data.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data["type"].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
data["country"].value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
data["release_year"].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
data["rating"].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %% [markdown]
# ### Handling the missing value

# %% [markdown]
# ### In column("director") we are replace missing value with previous Row values

# %%
data["director"] = data["director"].fillna(method='ffill')

# %% [markdown]
# ### In column("Description") we are replace missing value with previous Row values

# %%
data["cast"] = data["cast"].fillna(method='ffill')

# %%
data["country"] = data["country"].fillna(method='ffill')

# %%
data.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             1
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
data.dropna(axis = 0, inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ### grouping the data according to our country columns

# %%
data.groupby(["country"]).count()
# Out:
#                                                     show_id  type  title  \
# country
# , France, Algeria                                         1     1      1
# , South Korea                                             2     2      2
# Argentina                                                62    62     62
# Argentina, Brazil, France, Poland, Germany, Den...        1     1      1
# Argentina, Chile                                          3     3      3
# ...                                                     ...   ...    ...
# Venezuela                                                 1     1      1
# Venezuela, Colombia                                       1     1      1
# Vietnam                                                  10    10     10
# West Germany                                              1     1      1
# Zimbabwe                                                  1     1      1
#
#                                                     director  cast  \
# country
# ...

# %% [markdown]
# ### remove stopwatch from our description

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\faiza\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = stopwords.words('english')
def remove_stopwords(text):
    words = [word for word in text.split() if word.lower() not in stopwords]
    new_text = " ".join(words)
    return new_text

# %%
data["listed_in"] = data["listed_in"].apply(lambda x:remove_stopwords(x))

# %%
data["description"] = data["description"].apply(lambda x:remove_stopwords(x))

# %%
data["cast"] = data["cast"].apply(lambda x:remove_stopwords(x))

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water  Kirsten Johnson
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq
# 4      s5  TV Show           Kota Factory  Julien Leclercq
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 3  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ### count the number of word present in desciption columns

# %%
data['word_count_in_description'] = data['description'].apply(lambda x: len(str(x).split()))

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water  Kirsten Johnson
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq
# 4      s5  TV Show           Kota Factory  Julien Leclercq
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 3  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
data['word_count_in_listed_in'] = data['listed_in'].apply(lambda x: len(str(x).split()))

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water  Kirsten Johnson
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq
# 4      s5  TV Show           Kota Factory  Julien Leclercq
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 3  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
data['word_count_in_cast'] = data['cast'].apply(lambda x: len(str(x).split()))

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water  Kirsten Johnson
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq
# 4      s5  TV Show           Kota Factory  Julien Leclercq
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 3  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ### Conversion of date into dataframe date

# %%
type(data['date_added'][1])
# Out:
# str

# %%
data['date_added'] = pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water  Kirsten Johnson
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq
# 4      s5  TV Show           Kota Factory  Julien Leclercq
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country date_added  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa 2021-09-24
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa 2021-09-24
# 3  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  South Africa 2021-09-24
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...         India 2021-09-24
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ## Visulaztion

# %% [markdown]
# ### First we can take all data

# %%
sns.pairplot(data)
plt.show()

# %%
sns.scatterplot(y=data["type"], x=data["rating"])
plt.title("TYPE VS COUNTRY", fontsize=(25))
plt.show()

# %%
sns.lineplot(x=data["type"].head(20), y=data["rating"].head(20))
#plt.title("TYPE VS COUNTRY", fontsize=(25))
plt.show()

# %%
sns.displot(data=data, x="date_added", kind="kde")
plt.show()

# %%
sns.kdeplot(data=data, x="date_added")
plt.show()

# %%
sns.kdeplot(data=data)
plt.show()
